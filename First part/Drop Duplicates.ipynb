# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Datos.csv')

# %%
df
# Out:
#        Orden       Fecha       Medio           Vendedor Plataforma Comisión  \
# 0          1  06/08/2017      Propio  Directo en Tienda    Website       0%
# 1          1  06/08/2017      Propio  Directo en Tienda    Website       0%
# 2          1  06/08/2017      Propio  Directo en Tienda    Website       0%
# 3          1  06/08/2017      Propio  Directo en Tienda    Website       0%
# 4          1  06/08/2017      Propio  Directo en Tienda    Website       0%
# ...      ...         ...         ...                ...        ...      ...
# 63216   7500  16/03/2017  Influencer         gypseajain    Youtube      30%
# 63217   7500  16/03/2017  Influencer         gypseajain    Youtube      30%
# 63218   7500  16/03/2017  Influencer         gypseajain    Youtube      30%
# 63219   7500  16/03/2017  Influencer         gypseajain    Youtube      30%
# 63220   7500  16/03/2017  Influencer         gypseajain    Youtube      30%
#
# ...

# %%
## Drop Duplicates
df.drop_duplicates(subset = "Vendedor")
# Out:
#       Orden       Fecha       Medio            Vendedor Plataforma Comisión  \
# 0         1  06/08/2017      Propio   Directo en Tienda    Website       0%
# 14        2  26/10/2017      Propio     Publicidad Face   Facebook       0%
# 33        4  13/02/2017      Propio    Publicidad Insta  Instagram       0%
# 47        5  25/05/2017      Propio  Publicidad Youtube    Youtube       0%
# 57        6  21/07/2017  Influencer         melissaguin  Instagram      30%
# 59        7  12/11/2017  Influencer    aplinewithvyycan  Instagram      30%
# 62        9  07/11/2017  Influencer        anamontero22  Instagram      30%
# 78       11  27/11/2017  Influencer         karlagvzcia  Instagram      40%
# 93       13  28/07/2017  Influencer            epiclava  Instagram      30%
# 98       14  10/10/2017  Influencer  marisaamanzanolife  Instagram      30%
# 157      20  01/11/2017  Influencer         andreaheraz  Instagram      10%
# ...

# %%
## Drop duplicate pairs
df.drop_duplicates(subset = ["Vendedor", "Plataforma"])
# Out:
#       Orden       Fecha       Medio            Vendedor Plataforma Comisión  \
# 0         1  06/08/2017      Propio   Directo en Tienda    Website       0%
# 14        2  26/10/2017      Propio     Publicidad Face   Facebook       0%
# 33        4  13/02/2017      Propio    Publicidad Insta  Instagram       0%
# 47        5  25/05/2017      Propio  Publicidad Youtube    Youtube       0%
# 57        6  21/07/2017  Influencer         melissaguin  Instagram      30%
# 59        7  12/11/2017  Influencer    aplinewithvyycan  Instagram      30%
# 62        9  07/11/2017  Influencer        anamontero22  Instagram      30%
# 78       11  27/11/2017  Influencer         karlagvzcia  Instagram      40%
# 93       13  28/07/2017  Influencer            epiclava  Instagram      30%
# 98       14  10/10/2017  Influencer  marisaamanzanolife  Instagram      30%
# 157      20  01/11/2017  Influencer         andreaheraz  Instagram      10%
# ...

# %%
## Count values
df["Vendedor"].value_counts()
## You can add a sort
df["Vendedor"].value_counts(sort = True)
# Out:
# Publicidad Insta      12673
# Directo en Tienda      8532
# Publicidad Face        5938
# Publicidad Youtube     5007
# karlagvzcia            2860
# marianaguayoela        2322
# jimellanna             1177
# aplinewithvyycan       1138
# greciasotelovvv        1097
# dudabrnrons            1079
# abrahamojicar          1068
# marugshbolena          1040
# aleixploreuria         1017
# nathaliansrro          1017
# mariana.vn              976
# marisaamanzanolife      903
# daniexploradorarod      873
# anellaholldoll          850
# anamontero22            837
# jldom89                 801
# luckarovtes             791
# SanayNutri              780
# Nataliansfa             744
# moreofmarrr             647
# epiclava                619
# ximeguajardd            618
# reginaacosta314         580
# lescarpinteli           571
# adamgoneron             549
# carleycmountains        515
# celestezohmoran         508
# miriamvillalmals        507
# roberto_herlom88        494
# ...
